# %% [markdown]
# <a href="https://colab.research.google.com/github/Abidau/MachineLearning/blob/main/TG1_244107020212_NaufalAbidAurizky.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mne

# %% [markdown]
# ---
# # Tugas Praktikum
#
# ## Bagian 1
#
#  2. Instalasi Library

# %%
# a. PyPREP
# !pip install pyprep

# b. Scipy
# !pip install scipy

# c. wandb
# !pip install wandb

# d. pyECG
# !pip install pyECG
# Out:
# ...
#   Using cached pyECG-0.0.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# ...
#   Using cached ishneholterlib-2017.4.11.tar.gz (7.0 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached wfdb-2.2.1.tar.gz (94 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached pytest_cov-7.1.0-py3-none-any.whl.metadata (32 kB)
# ...
#   Using cached pycrc-0.11.0-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached nose-1.3.7-py3-none-any.whl.metadata (1.7 kB)
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.5/257.5 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 15.4 MB/s eta 0:00:00
# ...
#   Created wheel for ishneholterlib: filename=ishneholterlib-2017.4.11-py3-none-any.whl size=7504 sha256=7db637d1b49a6244200447c49739a1cd3cfd33ddf664f7954f68be38d6a930d4
#   Stored in directory: /root/.cache/pip/wheels/60/50/d1/db6b1d062f56ed24c391a2d51126d1341cc51381bed8a2de61
# ...

# %% [markdown]
# 3. Kegunaan Masing-Masing Library
#
# a. PyPREP
#
# PyPREP tersebut berguna untuk digunakan preprocessing EEG(electroencephalography) yang menangani noise dan masalah pada sinyal
#
# b. SciPy
#
# SciPy untuk menyediakan fungsi matematika dan ilmiah yang dapat mengolah data dan sinyal, seperti pengolahan sinyal `scipy.signal`, aljabar linier `scipy.linalg`, optimisasi `scipy.optimize`, statistik `scipy.stats`, integrasi numerik
#
# c. wandb
#
# wandb digunakan untuk mencatat dan memantau proses training model machine learning, contohnya dapat mencatat akurasi, loss, learning rate, konfigurasi model, perbandingan beberapa eksperimen
#
# d. pyECG
#
# pyECG digunakan untuk membaca dan menulis format dataset sinyal ECG(elektrokardiogram), contohnya format Physiobank WFDB(.hea/.dat) dan format Holter ISHNE(.ecg/.ann). Jadi lebih memudahkan proses ekstraksi sinyal ECG mentah dari file rekaman medis menjadi struktur data yang dapat langsung dioleh dengan python.

# %% [markdown]
# ### Bagian 2
#
# 1. Contoh tindakan melanggar etika dan hukum dalam penggunaan kecerdasan buatan
#
# Pada tahun 2025, pengadilan tinggi Inggris dan Wales menangani kasus dimana pengacara menggunakan chatbot AI generatif untuk riset hukum tanpa verifikasii yang mengakibatkan dokumen yang diajukan ke pengadilan berisi kutipan putusan fiktif hasil AI, dari 45 kutipan yang diajukan, 18 diantaranya kasus yang tidak pernah ada.
#
# Hakim Victoria Sharp menegaskan AI generatif tidak mempu melakukan riset hukum yang dapat diandalkan. Pengadilan menyatakan penggunaan AI tidak dilarang, namun pengacara tetap wajib memverifikasi hasilnya. Kasus ini adalah contoh pelanggaran etika profesi sekaligus pelanggaran hukum acara, dengan ancaman sanksi pidana maupun sanksi profesi. Kasus ini menggambarkan resiko hallucination pada AI generatif yang dapat merugikan pihak lain jika tidak diverifikasi
#
# Refrensi:
#
# - Bisnis.com. (2025, 8 Juni). Pengacara di Inggris Terancam Sanksi Berat Akibat Halusinasi Kecerdasan Buatan (AI). https://teknologi.bisnis.com/read/20250608/84/1883239/pengacara-di-inggris-terancam-sanksi-berat-akibat-halusinasi-kecerdasan-buatan-ai
# - SIP Law Firm. Implikasi Hukum dalam Penggunaan Kecerdasan Buatan (AI). https://siplawfirm.id/resources/implikasi-hukum-dalam-penggunaan-kecerdasan-buatan-ai
#
# 2. Dampak energi dan lingkungan dari pemanfaatan kecerdasan buatan
#
# ### Dampak terhadap Energi dan Lingkungan
#
# Pemanfaatan AI, khususnya model bahasa besar (LLM), membutuhkan daya komputasi besar sehingga berdampak pada konsumsi energi dan lingkungan. Studi terhadap lebih dari 2100 pusat data di AS menemukan pusat data menyumbang lebih dari 4% konsumsi listrik AS (56% dari bahan bakar fosil) dan menghasilkan lebih dari 105juta ton CO2. IEA memproyeksikan konsumsi listrik pusat data dunia meningkat dua kali lipat pada 2026 akibat beban kerja AI generatif. Kemudian sistem pendingin pusat data membutuhkan air dalam jumlah sangat besar (diperkirakan 1,3 sampai 1,8 triliun liter/tahun secara global pada 2030), serta memicu limbah elektronik dan penambangan mineral untuk perangkat keras
#
# ### Cara mengatasi
#
# - Energi terbarukan untuk menyuplai listrik pusat data, menurunkan intensitas karbon operasional AI
# - Efisiensi model (compression, quantization, distillation) untuk kebutuhan daya lebih rendah tanpa mengorbankan peforma
# -AI-driven energy management untuk mengoptimalkan pendinginan dan beban kerja secara real-time
# -Green data center seperti liquid cooling dan regulasi yang mendorong transisi berkelanjutan
#
# ### refrensi
#
# - Chien, A., et al. (2024). Environmental Burden of United States Data Centers in the Artificial Intelligence Era. arXiv:2411.09786. https://arxiv.org/pdf/2411.09786
# - Kompas.com. (2026, 1 Juli). Emisi Karbon Pusat Data Diprediksi Lebih Tinggi dari Perkiraan. https://lestari.kompas.com/read/2026/07/01/195441286/emisi-karbon-pusat-data-diprediksi-lebih-tinggi-dari-perkiraan
# - Medcom.id. (2025, 2 November). AI Diprediksi Konsumsi Lebih dari 50% Energi Data Center pada 2028, Solusinya? https://www.medcom.id/teknologi/news-teknologi/Rb1De83N-ai-diprediksi-konsumsi-lebih-dari-50-energi-data-center-pada-2028-solusinya
